# %%
import godot

import numpy as np
from godot.core import tempo, util, constants
from godot.core import autodif as ad
from godot.core.autodif import bridge as br
from godot.model import common
from godot import cosmos
from tqdm import tqdm
import time
import csv
# Out:
# Help on package godot.core.autodif in godot.core:
#
# NAME
#     godot.core.autodif - Automatic Differentiation
#
# DESCRIPTION
#
#     Classes
#     -------
#
#     .. autosummary::
#         :toctree: generated/
#         :template: custom-class-template.rst
#
#         Leaf
#         AbstractLeaf
#         BasicLeaf
#         NamedLeaf
#         Gradient
#         VectorGradient
#         Scalar
#         Vector
#         Matrix
#
#     .. todo::
#
#        Vector docstrings
#
#     .. todo::
#
#        Matrix docstrings
#
#     Functions
#     ---------
#
#     .. autosummary::
#         :toctree: generated/
#
#
#         getPartial
#         value
#         sign
#         gradient
#         parameters
#         leaf
#         partial
#         create
#         abs
#         square
#         cube
#         sqrt
#         exp
#         log
#         pow
#         sin
#         cos
#         tan
#         asin
#         acos
#         atan
#         atan2
#         sinh
#         cosh
#         tanh
#         asinh
#         acosh
#         atanh
#         norm
#         dot
#         cross
#         concatenate
#
#     .. todo::
#
#        Add type hints in docstrings
#
# PACKAGE CONTENTS
#     _autodif
#     bridge (package)
#     tests (package)
#
# FUNCTIONS
#     abs(...) method of builtins.PyCapsule instance
#         abs(x)
#
#         Compute absolute value, element-wise
#
#         Parameters
#         ----------
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#         array_like
#             The corresponding absolute values
#
#     acos(...) method of builtins.PyCapsule instance
#         acos(x)
#
#         Compute arc cosine, element-wise
#
#         Parameters
#         ----------
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#         array_like
#             The corresponding arc cosine
#
#     acosh(...) method of builtins.PyCapsule instance
#         acosh(x)
#
#         Compute hyperbolic arccosine, element-wise
#
#         Parameters
#         ----------
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#         array_like
#             The corresponding hyperbolic arccosine
#
#     asin(...) method of builtins.PyCapsule instance
#         asin(x)
#
#         Compute arcsine, element-wise
#
#         Parameters
#         ----------
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding arcsine
#
#     asinh(...) method of builtins.PyCapsule instance
#         asinh(x)
#
#         Compute hyperbolic arcsine, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding hyperbolic arcsine, if x is a scalar, output is a scalar
#
#     atan(...) method of builtins.PyCapsule instance
#         atan(x)
#
#         Compute arc tangent, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding arc tangent, if x is a scalar, output is a scalar
#
#     atan2(...) method of builtins.PyCapsule instance
#         atan2(x, y)
#
#         Compute arc tangent, element-wise choosing the quadrant correctly.
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#         y: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding arc tangent, if `x`, `y` are scalars, output is a scalar
#
#         Raises
#         ------
#         RuntimeError
#             If the size of `x` and `y` do not match
#
#
#         atan2(x, y)
#
#         Compute arc tangent, element-wise choosing the quadrant correctly.
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#         y: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding arc tangent, if `x`, `y` are scalars, output is a scalar
#
#         Raises
#         ------
#         RuntimeError
#             If the size of `x` and `y` do not match
#
#
#         atan2(x, y)
#
#         Compute arc tangent, element-wise choosing the quadrant correctly.
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#         y: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding arc tangent, if `x`, `y` are scalars, output is a scalar
#
#         Raises
#         ------
#         RuntimeError
#             If the size of `x` and `y` do not match
#
#     atanh(...) method of builtins.PyCapsule instance
#         atanh(x)
#
#         Compute hyperbolic arctangent, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding hyperbolic arctangent
#
#     concatenate(...) method of builtins.PyCapsule instance
#
#     cos(...) method of builtins.PyCapsule instance
#         cos(x)
#
#         Compute cosine, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding cosine
#
#     cosh(...) method of builtins.PyCapsule instance
#         cosh(x)
#
#         Compute hyperbolic cosine, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding hyperbolic cosine
#
#     create(...) method of builtins.PyCapsule instance
#         create()
#
#         create()
#
#         create()
#
#         create()
#
#         create()
#
#         create()
#
#         create()
#
#         create()
#
#         create()
#
#     cross(...) method of builtins.PyCapsule instance
#         cross(x,y)
#
#         This function computes the cross product of 2 vectors.
#
#         Parameters
#         ----------
#         x : array_like
#           first vector to be multiplied
#         y : array_like
#           second vector to be multiplied
#
#         Returns
#         -------
#
#         array_like
#           Vector cross product
#
#         Raises
#         ------
#         RuntimeError
#             If the size of x and y do not permit multiplication
#
#         Notes
#         -----
#
#         .. warning:: Currently if vectors with dimension other than 3 are used, the cross product
#                      will not raise an error, but will try to cast the vector to a 3D one....
#
#     cube(...) method of builtins.PyCapsule instance
#         cube(x)
#
#         Compute cube, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding cube
#
#     dot(...) method of builtins.PyCapsule instance
#         godot.core.autodif.dot(x, y)
#
#         This method computes the matrix/vector dot product for autodif and numpy types including mixed types.
#
#         Parameters
#         ----------
#         x : array_like
#           first array to be multiplied
#         y : array_like
#           second array to be multiplied
#
#         Returns
#         -------
#         array_like
#           Matrix product
#
#         Raises
#         ------
#         RuntimeError
#             If the size of x and y do not permit multiplication
#
#     eigenvalues(...) method of builtins.PyCapsule instance
#         eigenvalues(x: array_like | :class:`godot.core.autodif.Matrix`) -> List[:class:`godot.core.autodif.ComplexScalar`]
#
#         Compute Eigenvalues of matrix with gradients
#
#         Output is complex, use real() and imag() operators
#
#         .. warning::
#             This feature is **experimental** and may change in future releases.
#             Use with caution.
#
#         Parameters
#         ----------
#         x: array_like | :class:`godot.core.autodif.Matrix`
#             The matrix whos eigenvalues are sought
#
#         Returns
#         -------
#
#         List[:class:`godot.core.autodif.ComplexScalar`]
#             A list of complex eigenvalues of the matrix
#
#     exp(...) method of builtins.PyCapsule instance
#         exp(x)
#
#         Compute exponential, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding exponential
#
#     getPartial(...) method of builtins.PyCapsule instance
#         getPartial(x, leaf)
#                 Returns The gradient of `x` with respect to `leaf`
#
#         getPartial(x, leaf)
#                 Returns The gradient of `x` with respect to `leaf`
#
#     gradient(...) method of builtins.PyCapsule instance
#         gradient(x)
#                 Returns `x.gradient()`
#
#         gradient(x)
#                 Returns `x.gradient()`
#
#         gradient(x)
#                 Returns `x.gradient()`
#
#     hstack(...) method of builtins.PyCapsule instance
#         vstack()
#
#     inverse(...) method of builtins.PyCapsule instance
#         eigenvalues(x: array_like | :class:`godot.core.autodif.Matrix`)  -> :class:`godot.core.autodif.Matrix`
#
#         Compute inverse of matrix with gradients
#
#         .. warning::
#             This feature is **experimental** and may change in future releases.
#             Use with caution.
#
#
#         Parameters
#         ----------
#         x: array_like | :class:`godot.core.autodif.Matrix`
#             The matrix whos inverse is sought
#
#         Returns
#         -------
#
#         array_like | :class:`godot.core.autodif.Matrix`
#             The inverse of the matrix
#
#     leaf(...) method of builtins.PyCapsule instance
#         leaf(x)
#                 Returns `x.leaf()`
#
#         leaf(x)
#                 Returns `x.leaf()`
#
#         leaf(x)
#                 Returns `x.leaf()`
#
#     log(...) method of builtins.PyCapsule instance
#         log(x)
#
#         Compute natural logarithm, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding natural logarithm
#
#     log10(...) method of builtins.PyCapsule instance
#         log10(x)
#
#         Compute base 10 logarithm, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.xdouble` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.xdouble` |  array_like
#             The corresponding base 10 logarithm
#
#     mod(...) method of builtins.PyCapsule instance
#         mod(x, y)
#
#         Returns the element-wise remainder of division.
#
#         Computes the remainder complementary to the floor_divide function.
#         It is equivalent to the Python modulus operator``x % y`` and has the same sign as the divisor y.
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.xdouble` | array_like
#             input array
#
#         y: :class:`float`
#             divisor
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.xdouble` |  array_like
#             The corresponding remainder of division,
#
#         mod(x, y)
#
#         Returns the element-wise remainder of division.
#
#         Computes the remainder complementary to the floor_divide function.
#         It is equivalent to the Python modulus operator``x % y`` and has the same sign as the divisor y.
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.xdouble` | array_like
#             input array
#
#         y: :class:`float`
#             divisor
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.xdouble` |  array_like
#             The corresponding remainder of division,
#
#     norm(...) method of builtins.PyCapsule instance
#         norm(x)
#
#         Compute Euclidian norm, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding Euclidian norm
#
#     parameters(...) method of builtins.PyCapsule instance
#         parameters(x)
#                 Returns `[p.leaf()for p in x]`
#
#         parameters(x)
#                 Returns `[p.leaf()for p in x]`
#
#         parameters(x)
#                 Returns `[p.leaf()for p in x]`
#
#     partial(...) method of builtins.PyCapsule instance
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#         partial()
#
#     pow(...) method of builtins.PyCapsule instance
#         pow(x,y)
#
#         Compute x raised to power y, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#         y: float | :class:`godot.core.autodif.xdouble`
#             power
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The element-wise `x` to power `y`
#
#         pow(x,y)
#
#         Compute x raised to power y, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#         y: float | :class:`godot.core.autodif.xdouble`
#             power
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The element-wise `x` to power `y`
#
#         pow(x,y)
#
#         Compute x raised to power y, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#         y: float | :class:`godot.core.autodif.xdouble`
#             power
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The element-wise `x` to power `y`
#
#     sign(...) method of builtins.PyCapsule instance
#         sign(x)
#
#         Compute sign of the value, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding sign
#
#         sign(x)
#
#         Compute sign of the value, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding sign
#
#     sin(...) method of builtins.PyCapsule instance
#         sin(x)
#
#         Compute sine, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding sine
#
#     sinh(...) method of builtins.PyCapsule instance
#         sinh(x)
#
#         Compute hyperbolic sine, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding hyperbolic sine
#
#     sqrt(...) method of builtins.PyCapsule instance
#         sqrt(x)
#
#         Compute square root, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding square root
#
#     square(...) method of builtins.PyCapsule instance
#         square(x)
#
#         Compute square, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding square
#
#     tan(...) method of builtins.PyCapsule instance
#         tan(x)
#
#         Compute tangent, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding tangent
#
#     tanh(...) method of builtins.PyCapsule instance
#         tanh(x)
#
#         Compute hyperbolic tangent, element-wise
#
#         Parameters
#         ----------
#
#         x: :class:`float` | :class:`godot.core.autodif.Scalar` | array_like
#             input array
#
#         Returns
#         -------
#
#         :class:`float` | :class:`godot.core.autodif.Scalar` |  array_like
#             The corresponding hyperbolic tangent
#
#     value(...) method of builtins.PyCapsule instance
#         value(x)
#         Return the value of x
#
#         value(x)
#         Return the value of x
#
#         value(x)
#         Return the value of x
#
#         value(x)
#         Return the value of x
#
#         value(x)
#         Return the value of x
#
#         value(x)
#         Return the value of x
#
#     vstack(...) method of builtins.PyCapsule instance
#         vstack()
#
# FILE
#     /home/dyb/Documents/GitHub/GODOTWork/venv/lib/python3.12/site-packages/godot/core/autodif/__init__.py
